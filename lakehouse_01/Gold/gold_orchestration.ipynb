# %%
notebooks = [
    "/Workspace/Databricks_project_01/databricks_project_01/lakehouse_01/Gold/Gold_cust",
    "/Workspace/Databricks_project_01/databricks_project_01/lakehouse_01/Gold/gold_products",
    "/Workspace/Databricks_project_01/databricks_project_01/lakehouse_01/Gold/gold_sales"
]

for nb in notebooks:
    try:
        result = dbutils.notebook.run(nb, 600)
        print(f"Notebook {nb} executed successfully.")
    except Exception as e:
        print(f"Error executing notebook {nb}: {str(e)}")
