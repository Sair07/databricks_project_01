# %%
notebooks = [
    "/Workspace/Databricks_project_01/databricks_project_01/lakehouse_01/Silver/CRM/Silver_CRM_Cust",
    "/Workspace/Databricks_project_01/databricks_project_01/lakehouse_01/Silver/CRM/Silver_CRM_prod",
    "/Workspace/Databricks_project_01/databricks_project_01/lakehouse_01/Silver/CRM/Silver_CRM_sales",
    "/Workspace/Databricks_project_01/databricks_project_01/lakehouse_01/Silver/ERP/Silver_ERP_cat",
    "/Workspace/Databricks_project_01/databricks_project_01/lakehouse_01/Silver/ERP/Silver_ERP_Cust",
    "/Workspace/Databricks_project_01/databricks_project_01/lakehouse_01/Silver/ERP/Silver_ERP_Loc"
]

for nb in notebooks:
    try:
        result = dbutils.notebook.run(nb, 0, {"run_id": "123"})
        print(f"{nb} finished with result: {result}")
    except Exception as e:
        print(f"{nb} failed with error: {str(e)}")
        break
